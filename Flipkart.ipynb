# %%
url = 'https://www.flipkart.com/laptops/pr?sid=6bo%2Cb5g&fm=neo%2Fmerchandising&iid=M_8b3b3f65-7ceb-4375-912c-d2bcdde87c58_1_372UD5BXDFYS_MC.34WHNYFH5V2Y&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_13_L1_view-all&cid=34WHNYFH5V2Y&p%5B%5D=facets.brand%255B%255D%3DAPPLE&otracker=clp_metro_expandable_6_26.metroExpandable.METRO_EXPANDABLE_Apple_laptops-store_SKIHMOPFPDC3_wp9&fm=neo%2Fmerchandising&iid=M_b4d0e2ef-aaac-4e7e-9272-9b8be53c2dc5_26.SKIHMOPFPDC3&ppt=clp&ppn=laptops-store&ssid=j5fwd6niaz0hnchs1645514684273&page=1'

# %%
import os

# %%
os.chdir('C:\Scripting')

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests

# %%
browser = webdriver.Firefox()

# %%
browser.get(url)

# %%
html = browser.page_source

# %%
soup = BeautifulSoup(html,'lxml')

# %%
prod_name = [i.text.strip() for i in soup.select('div._4rR01T')]

# %%
price = [''.join((i.text.strip().split('₹')[1].split(','))) for i in soup.select('div._25b18c')]

# %%
rate = [i.find_all('div')[0].text.strip() for i in soup.select('div.gUuXy-')]

# %%
total_rate = [''.join(i.text.strip().split(' ')[0].split(',')) for i in soup.select('span._2_R_DZ')]

# %%
total_rev = [i.text.split('Ratings\xa0&\xa0')[1].split(' ')[0] for i in soup.select('span._2_R_DZ')]

# %%
spec = [i.text for i in soup.select('div.fMghEO')]

# %%
import pandas as pd
def flipkart():
    prod_name = [i.text.strip() for i in soup.select('div._4rR01T')]
    price = [''.join((i.text.strip().split('₹')[1].split(','))) for i in soup.select('div._25b18c')]
    rate = [i.find_all('div')[0].text.strip() for i in soup.select('div.gUuXy-')]
    total_rate = [''.join(i.text.strip().split(' ')[0].split(',')) for i in soup.select('span._2_R_DZ')]
    total_rev = [i.text.split('Ratings\xa0&\xa0')[1].split(' ')[0] for i in soup.select('span._2_R_DZ')]
    spec = [i.text for i in soup.select('div.fMghEO')]
    return pd.DataFrame({'Product Name':prod_name,
                         'Price':price,
                         'Rating out of 5':rate,
                         'Total Ratings':total_rate,
                         'Total Reviews':total_rev,
                         'Device Features':spec})

# %%
tables=[]
from tqdm import tqdm
for i in range(1,3):
    urls=url.format(i)
    browser.get(url)
    html=browser.page_source
    soup=BeautifulSoup(html,'lxml')
    tables.append(flipkart())

# %%
df=pd.concat(tables,axis=0)
df.style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_265d9">
#   <thead>
#     <tr>
#       <th id="T_265d9_level0_col0" class="col_heading level0 col0" >Product Name</th>
#       <th id="T_265d9_level0_col1" class="col_heading level0 col1" >Price</th>
#       <th id="T_265d9_level0_col2" class="col_heading level0 col2" >Rating out of 5</th>
#       <th id="T_265d9_level0_col3" class="col_heading level0 col3" >Total Ratings</th>
#       <th id="T_265d9_level0_col4" class="col_heading level0 col4" >Total Reviews</th>
#       <th id="T_265d9_level0_col5" class="col_heading level0 col5" >Device Features</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_265d9_row0_col0" class="data row0 col0" >APPLE 2020 Macbook Air M1 - (8 GB/256 GB SSD/Mac OS Big Sur) MGN63HN/A</td>
#       <td id="T_265d9_row0_col1" class="data row0 col1" >90890</td>
#       <td id="T_265d9_row0_col2" class="data row0 col2" >4.7</td>
#       <td id="T_265d9_row0_col3" class="data row0 col3" >6459</td>
#       <td id="T_265d9_row0_col4" class="data row0 col4" >613</td>
#       <td id="T_265d9_row0_col5" class="data row0 col5" >Apple M1 Processor8 GB DDR4 RAMMac OS Operating System256 GB SSD33.78 cm (13.3 inch) DisplayBuilt-in Apps: iMovie, Siri, GarageBand, Pages, Numbers, Photos, Keynote, Safari, Mail, FaceTime, Messages, Maps, Stocks, Home, Voice Memos, Notes, Calendar, Contacts, Reminders, Photo Booth, Preview, Books, App Store, Time Machine, TV, Music, Podcasts, Find My, QuickTime Player1 Year Limited Warra­nty</td>
#     </tr>
#     <tr>
#       <td id="T_265d9_row1_col0" class="data row1 col0" >APPLE 2020 Macbook Air M1 - (8 GB/256 GB SSD/Mac OS Big Sur) MGND3HN/A</td>
#       <td id="T_265d9_row1_col1" class="data row1 col1" >86690</td>
#       <td id="T_265d9_row1_col2" class="data row1 col2" >4.7</td>
#       <td id="T_265d9_row1_col3" class="data row1 col3" >6459</td>
#       <td id="T_265d9_row1_col4" class="data row1 col4" >613</td>
#       <td id="T_265d9_row1_col5" class="data row1 col5" >Apple M1 Processor8 GB DDR4 RAMMac OS Operating System256 GB SSD33.78 cm (13.3 inch) DisplayBuilt-in Apps: iMovie, Siri, GarageBand, Pages, Numbers, Photos, Keynote, Safari, Mail, FaceTime, Messages, Maps, Stocks, Home, Voice Memos, Notes, Calendar, Contacts, Reminders, Photo Booth, Preview, Books, App Store, Time Machine, TV, Music, Podcasts, Find My, QuickTime Player1 Year Limited Warra­nty</td>
#     </tr>
#     <tr>
#       <td id="T_265d9_row2_col0" class="data row2 col0" >APPLE 2020 Macbook Air M1 - (8 GB/256 GB SSD/Mac OS Big Sur) MGN93HN/A</td>
#       <td id="T_265d9_row2_col1" class="data row2 col1" >88990</td>
#       <td id="T_265d9_row2_col2" class="data row2 col2" >4.7</td>
#       <td id="T_265d9_row2_col3" class="data row2 col3" >6459</td>
#       <td id="T_265d9_row2_col4" class="data row2 col4" >613</td>
#       <td id="T_265d9_row2_col5" class="data row2 col5" >Apple M1 Processor8 GB DDR4 RAMMac OS Operating System256 GB SSD33.78 cm (13.3 inch) DisplayBuilt-in Apps: iMovie, Siri, GarageBand, Pages, Numbers, Photos, Keynote, Safari, Mail, FaceTime, Messages, Maps, Stocks, Home, Voice Memos, Notes, Calendar, Contacts, Reminders, Photo Booth, Preview, Books, App Store, Time Machine, TV, Music, Podcasts, Find My, QuickTime Player1 Year Limited Warra­nty</td>
#     </tr>
#     <tr>
#       <td id="T_265d9_row3_col0" class="data row3 col0" >APPLE 2020 Macbook Air M1 - (8 GB/512 GB SSD/Mac OS Big Sur) MGN73HN/A</td>
#       <td id="T_265d9_row3_col1" class="data row3 col1" >109990</td>
#       <td id="T_265d9_row3_col2" class="data row3 col2" >4.7</td>
#       <td id="T_265d9_row3_col3" class="data row3 col3" >757</td>
#       <td id="T_265d9_row3_col4" class="data row3 col4" >91</td>
#       <td id="T_265d9_row3_col5" class="data row3 col5" >Apple M1 Processor8 GB DDR4 RAMMac OS Operating System512 GB SSD33.78 cm (13.3 inch) DisplayBuilt-in Apps: iMovie, Siri, GarageBand, Pages, Numbers, Photos, Keynote, Safari, Mail, FaceTime, Messages, Maps, Stocks, Home, Voice Memos, Notes, Calendar, Contacts, Reminders, Photo Booth, Preview, Books, App Store, Time Machine, TV, Music, Podcasts, Find My, QuickTime Player1 Year Limited Warra­nty</td>
#     </tr>
#     <tr>
#       <td id="T_265d9_row4_col0" class="data row4 col0" >APPLE MacBook Air M1 - (16 GB/256 GB SSD/Mac OS Big Sur) Z124J005KD</td>
#       <td id="T_265d9_row4_col1" class="data row4 col1" >105990</td>
#       <td id="T_265d9_row4_col2" class="data row4 col2" >4.5</td>
#       <td id="T_265d9_row4_col3" class="data row4 col3" >11</td>
#       <td id="T_265d9_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_265d9_row4_col5" class="data row4 col5" >Apple M1 Processor16 GB DDR4 RAMMac OS Operating System256 GB SSD33.78 cm (13.3 inch) DisplayBuilt-in Apps: iMovie, Siri, GarageBand, Pages, Numbers, Photos, Keynote, Safari, Mail, FaceTime, Messages, Maps, Stocks, Home, Voice Memos, Notes, Calendar, Contacts, Reminders, Photo Booth, Preview, Books, App Store, Time Machine, TV, Music, Podcasts, Find My, QuickTime Player1 Year Limited Warranty</td>
#     </tr>
#     <tr>
#       <td id="T_265d9_row5_col0" class="data row5 col0" >APPLE MacBook Air M1 - (16 GB/256 GB SSD/Mac OS Big Sur) Z124J001KD</td>
#       <td id="T_265d9_row5_col1" class="data row5 col1" >105990</td>
#       <td id="T_265d9_row5_col2" class="data row5 col2" >4.5</td>
#       <td id="T_265d9_row5_col3" class="data row5 col3" >11</td>
#       <td id="T_265d9_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_265d9_row5_col5" class="data row5 col5" >Apple M1 Processor16 GB DDR4 RAMMac OS Operating System256 GB SSD33.78 cm (13.3 inch) DisplayBuilt-in Apps: iMovie, Siri, GarageBand, Pages, Numbers, Photos, Keynote, Safari, Mail, FaceTime, Messages, Maps, Stocks, Home, Voice Memos, Notes, Calendar, Contacts, Reminders, Photo Booth, Preview, Books, App Store, Time Machine, TV, Music, Podcasts, Find My, QuickTime Player1 Year Limited Warranty</td>
#     </tr>
#     <tr>
#       <td id="T_265d9_row6_col0" class="data row6 col0" >APPLE 2021 Macbook Pro M1 Pro - (16 GB/512 GB SSD/Mac OS Monterey) MK183HN/A</td>
#       <td id="T_265d9_row6_col1" class="data row6 col1" >239890</td>
#       <td id="T_265d9_row6_col2" class="data row6 col2" >4.8</td>
#       <td id="T_265d9_row6_col3" class="data row6 col3" >33</td>
#       <td id="T_265d9_row6_col4" class="data row6 col4" >8</td>
#       <td id="T_265d9_row6_col5" class="data row6 col5" >Apple M1 Pro Processor16 GB Unified Memory RAMMac OS Operating System512 GB SSD41.15 cm (16.2 inch) DisplayiMovie, Siri, GarageBand, Pages, Numbers, Photos, Keynote, Safari, Mail, FaceTime, Messages, Maps, Stocks, Home, Voice Memos, Notes, Calendar, Contacts, Reminders, Photo Booth, Preview, Books, App Store, Time Machine, TV, Music, Podcasts, Find My, QuickTime Player1 Year Limited Warranty</td>
#     </tr>
#     <tr>
#       <td id="T_265d9_row7_col0" class="data row7 col0" >APPLE 2020 Macbook Air M1 - (8 GB/512 GB SSD/Mac OS Big Sur) MGNA3HN/A</td>
#       <td id="T_265d9_row7_col1" class="data row7 col1" >109990</td>
#       <td id="T_265d9_row7_col2" class="data row7 col2" >4.7</td>
#       <td id="T_265d9_row7_col3" class="data row7 col3" >757</td>
#       <td id="T_265d9_row7_col4" class="data row7 col4" >91</td>
#       <td id="T_265d9_row7_col5" class="data row7 col5" >Apple M1 Processor8 GB DDR4 RAMMac OS Operating System512 GB SSD33.78 cm (13.3 inch) DisplayBuilt-in Apps: iMovie, Siri, GarageBand, Pages, Numbers, Photos, Keynote, Safari, Mail, FaceTime, Messages, Maps, Stocks, Home, Voice Memos, Notes, Calendar, Contacts, Reminders, Photo Booth, Preview, Books, App Store, Time Machine, TV, Music, Podcasts, Find My, QuickTime Player1 Year Limited Warra­nty</td>
#     </tr>
#     <tr>
#       <td id="T_265d9_row8_col0" class="data row8 col0" >APPLE MacBook Air M1 - (16 GB/512 GB SSD/Mac OS Big Sur) Z124J003KD</td>
#       <td id="T_265d9_row8_col1" class="data row8 col1" >127990</td>
#       <td id="T_265d9_row8_col2" class="data row8 col2" >4.5</td>
#       <td id="T_265d9_row8_col3" class="data row8 col3" >11</td>
#       <td id="T_265d9_row8_col4" cla

# %%
df.shape
# Out:
# (48, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Product Name     48 non-null     object
#  1   Price            48 non-null     object
#  2   Rating out of 5  48 non-null     object
#  3   Total Ratings    48 non-null     object
#  4   Total Reviews    48 non-null     object
#  5   Device Features  48 non-null     object
# dtypes: object(6)
# memory usage: 2.6+ KB

# %%
df['Price'] = df['Price'].astype('int64')
df['Rating out of 5'] = df['Rating out of 5'].astype('float64')
df['Total Ratings'] = df['Total Ratings'].astype('int64')
df['Total Reviews'] = df['Total Reviews'].astype('int64')
df['Device Features'] = df['Device Features'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Product Name     48 non-null     object
#  1   Price            48 non-null     int64
#  2   Rating out of 5  48 non-null     float64
#  3   Total Ratings    48 non-null     int64
#  4   Total Reviews    48 non-null     int64
#  5   Device Features  48 non-null     category
# dtypes: category(1), float64(1), int64(3), object(1)
# memory usage: 2.7+ KB

# %%
df.to_csv('Flipkart.csv',index=False)
